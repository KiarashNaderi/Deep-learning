# %%
# prompt: کد شبکه عصبی مصنوعی بده

import tensorflow as tf

# تعریف مدل
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# کامپایل مدل
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# آموزش مدل
model.fit(x_train, y_train, epochs=10)

# ارزیابی مدل
loss, accuracy = model.evaluate(x_test,  y_test, verbose=2)
print('Loss:', loss)
print('Accuracy:', accuracy)

# %% [markdown]
# **Tensorflow**

# %%
import tensorflow as tf

# %% [markdown]
# **data structures**

# %%
# adad= bedone boad
a=tf.constant(1)
a
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
b=tf.constant([1,2])
b
# bordar 1 boad ast
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([1, 2], dtype=int32)>

# %%
c=tf.constant([[1,2,3],[4,5,6]])
#matris 2boadi ast
c
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)>

# %%
d=tf.constant([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])
d
# Out:
# <tf.Tensor: shape=(2, 2, 3), dtype=int32, numpy=
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]], dtype=int32)>

# %% [markdown]
# **Diffent operations**

# %%
a=tf.constant([1,2])
b=tf.constant([3,4])
c=tf.add(a,b)
c
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([4, 6], dtype=int32)>

# %%
d=tf.subtract(a,b)
d.numpy()
# Out:
# array([-2, -2], dtype=int32)

# %%
e=tf.multiply(a,b)
e.numpy()
# Out:
# array([3, 8], dtype=int32)

# %%
a = tf.constant([[1,2]])  # Reshape to a 2D tensor
b = tf.constant([[3],[4]])  # Reshape to a 2D tensor with 2 rows and 1 column
f = tf.matmul(a, b)
f
# Out:
# <tf.Tensor: shape=(1, 1), dtype=int32, numpy=array([[11]], dtype=int32)>

# %% [markdown]
# **reshape**

# %%
a=tf.constant([1,2,3,4])
a.shape
# Out:
# TensorShape([4])

# %%
b=tf.reshape(a,shape=(2,2))
b
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
#operations
x=tf.constant([[1,2],[3,4]])
x
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
b=tf.square(x)
b
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 1,  4],
#        [ 9, 16]], dtype=int32)>

# %%
#min/max
y=tf.constant([[1,2],[3,4]])
y
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
max=tf.reduce_max(y)
max.numpy()
# Out:
# 4
