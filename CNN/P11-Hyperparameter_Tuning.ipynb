# %%
# Load MNIST

from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# Visualize the first input

import matplotlib.pyplot as plt

plt.imshow(X_train[0])

# %%
# Create Adam Optimizer

from tensorflow.keras.optimizers import Adam

opt_1 = Adam(learning_rate=0.001)

# %%
# Base Model (Model 1)

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

model_1 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(10, activation='softmax')])

model_1.compile(optimizer=opt_1, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_1.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4721 - accuracy: 0.8748 - val_loss: 0.3077 - val_accuracy: 0.9146
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3035 - accuracy: 0.9154 - val_loss: 0.2797 - val_accuracy: 0.9223
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2828 - accuracy: 0.9205 - val_loss: 0.2783 - val_accuracy: 0.9226
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2730 - accuracy: 0.9236 - val_loss: 0.2707 - val_accuracy: 0.9231
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2664 - accuracy: 0.9251 - val_loss: 0.2718 - val_accuracy: 0.9242
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2615 - accuracy: 0.9265 - val_loss: 0.2674 - val_accuracy: 0.9258
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2581 - accuracy: 0.9284 - val_loss: 0.2642 - val_accuracy: 0.9258
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2553 - accuracy: 0.9295 - val_loss: 0.2619 - val_accuracy: 0.9269
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2530 - accuracy: 0.9296 - val_loss: 0.2675 - val_accuracy: 0.9256
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2504 - accuracy: 0.9309 - val_loss: 0.2646 - val_accuracy: 0.9275

# %%
# Adding number of parameters (Model 2)

opt_2 = Adam(learning_rate=0.001)

model_2 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(32, activation='relu'),
                     layers.Dense(10, activation='softmax')])

model_2.compile(optimizer=opt_2, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_2.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3652 - accuracy: 0.8993 - val_loss: 0.2287 - val_accuracy: 0.9321
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1942 - accuracy: 0.9441 - val_loss: 0.1760 - val_accuracy: 0.9462
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1532 - accuracy: 0.9549 - val_loss: 0.1463 - val_accuracy: 0.9561
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1283 - accuracy: 0.9621 - val_loss: 0.1337 - val_accuracy: 0.9602
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1113 - accuracy: 0.9669 - val_loss: 0.1275 - val_accuracy: 0.9620
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0982 - accuracy: 0.9706 - val_loss: 0.1345 - val_accuracy: 0.9601
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0896 - accuracy: 0.9727 - val_loss: 0.1130 - val_accuracy: 0.9664
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0812 - accuracy: 0.9749 - val_loss: 0.1096 - val_accuracy: 0.9676
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0747 - accuracy: 0.9768 - val_loss: 0.1102 - val_accuracy: 0.9671
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0693 - accuracy: 0.9791 - val_loss: 0.1036 - val_accuracy: 0.9699

# %%
# Increasing the learning rate (Model 3)

opt_3 = Adam(learning_rate=0.00001)

model_3 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(32, activation='relu'),
                     layers.Dense(10, activation='softmax')])

model_3.compile(optimizer=opt_3, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_3.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.0107 - accuracy: 0.3754 - val_loss: 1.7020 - val_accuracy: 0.5719
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.4742 - accuracy: 0.6490 - val_loss: 1.2492 - val_accuracy: 0.7230
# Epoch 3/10
# 1517/1875 [=======================>......] - ETA: 1s - loss: 1.1373 - accuracy: 0.7499
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7a45c86878ad> in <module>()
#      11 model_3.compile(optimizer=opt_3, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      12
# ---> 13 model_3.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1206         callbacks.on_epoch_begin(epoch)
#    1207         with data_handler.catch_stop_iteration():
# -> 1208           for step in data_handler.steps():
#    1209             with tf.profiler.experimental.Trace(
#    1210                 'train',
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in steps(self)
#    1248       if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1249         break
# -> 1250       original_spe = self._steps_per_execution.numpy().item()
#    1251       can_run_full_execution = (
#    1252           original_spe == 1 or
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     643   def numpy(self):
#     644     if context.executing_eagerly():
# --> 645       return self.read_value().numpy()
#     646     raise NotImplementedError(
#     647         "numpy() is only available when eager execution is enabled.")
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# Greatly add number of parameters (Model 4)

opt_4 = Adam(learning_rate=0.001)

model_4 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(128, activation='relu'),
                     layers.Dense(128, activation='relu'),
                     layers.Dense(10, activation='softmax')])

model_4.compile(optimizer=opt_4, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_4.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.2297 - accuracy: 0.9330 - val_loss: 0.1159 - val_accuracy: 0.9639
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0985 - accuracy: 0.9693 - val_loss: 0.0887 - val_accuracy: 0.9707
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0680 - accuracy: 0.9785 - val_loss: 0.0914 - val_accuracy: 0.9728
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0518 - accuracy: 0.9829 - val_loss: 0.0835 - val_accuracy: 0.9746
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0426 - accuracy: 0.9862 - val_loss: 0.0773 - val_accuracy: 0.9763
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0336 - accuracy: 0.9888 - val_loss: 0.0749 - val_accuracy: 0.9788
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0277 - accuracy: 0.9909 - val_loss: 0.0951 - val_accuracy: 0.9742
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0243 - accuracy: 0.9918 - val_loss: 0.0939 - val_accuracy: 0.9754
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0871 - val_accuracy: 0.9787
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0208 - accuracy: 0.9934 - val_loss: 0.1014 - val_accuracy: 0.9766

# %%
# Add Regularization / Dropout to reduce overfitting

from tensorflow.keras.regularizers import L2

opt_5 = Adam(learning_rate=0.001)

model_5 = Sequential([layers.Input((28, 28)),
                     layers.Lambda(lambda x: x / 255),
                     layers.Flatten(),
                     layers.Dense(128, activation='relu', kernel_regularizer=L2(0.001)),
                     layers.Dropout(0.05),
                     layers.Dense(128, activation='relu', kernel_regularizer=L2(0.001)),
                     layers.Dropout(0.05),
                     layers.Dense(128, activation='relu', kernel_regularizer=L2(0.001)),
                     layers.Dropout(0.05),
                     layers.Dense(10, activation='softmax')])

model_5.compile(optimizer=opt_5, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_5.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5173 - accuracy: 0.9187 - val_loss: 0.3380 - val_accuracy: 0.9527
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3048 - accuracy: 0.9554 - val_loss: 0.2447 - val_accuracy: 0.9657
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2590 - accuracy: 0.9613 - val_loss: 0.2241 - val_accuracy: 0.9698
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2442 - accuracy: 0.9636 - val_loss: 0.2100 - val_accuracy: 0.9728
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2293 - accuracy: 0.9663 - val_loss: 0.2067 - val_accuracy: 0.9741
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2260 - accuracy: 0.9664 - val_loss: 0.2221 - val_accuracy: 0.9683
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2197 - accuracy: 0.9668 - val_loss: 0.2169 - val_accuracy: 0.9677
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2173 - accuracy: 0.9666 - val_loss: 0.2099 - val_accuracy: 0.9683
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2111 - accuracy: 0.9688 - val_loss: 0.2214 - val_accuracy: 0.9631
# Epoch 10/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2110 - accuracy: 0.9681 - val_loss: 0.2087 - val_accuracy: 0.9673

# %%
# Increase number of epochs

model_5.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2100 - accuracy: 0.9677 - val_loss: 0.2109 - val_accuracy: 0.9685
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2054 - accuracy: 0.9688 - val_loss: 0.2125 - val_accuracy: 0.9681
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2030 - accuracy: 0.9690 - val_loss: 0.2036 - val_accuracy: 0.9657
# Epoch 4/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2048 - accuracy: 0.9678 - val_loss: 0.2000 - val_accuracy: 0.9713
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2024 - accuracy: 0.9684 - val_loss: 0.2155 - val_accuracy: 0.9646
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1984 - accuracy: 0.9701 - val_loss: 0.1851 - val_accuracy: 0.9734
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1990 - accuracy: 0.9698 - val_loss: 0.1823 - val_accuracy: 0.9730
# Epoch 8/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1976 - accuracy: 0.9694 - val_loss: 0.1840 - val_accuracy: 0.9721
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1979 - accuracy: 0.9693 - val_loss: 0.1860 - val_accuracy: 0.9742
# Epoch 10/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1981 - accuracy: 0.9698 - val_loss: 0.1845 - val_accuracy: 0.9738
